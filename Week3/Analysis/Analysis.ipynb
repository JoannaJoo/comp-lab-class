# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data=np.loadtxt("potential.xvg",skiprows=24)

# %%
plt.plot(data[:,0],data[:,1])
plt.xlabel('Energy minimization step')
plt.ylabel('Potential Energy (kJ/mol)')
plt.title('Energy minimization')
# Out:
# Text(0.5, 1.0, 'Energy minimization')

# %%
data2=np.loadtxt("temperature.xvg",skiprows=24)

# %%
plt.plot(data2[:,0],data2[:,1])
plt.xlabel('Time (ps)')
plt.ylabel('Temperature (K)')
plt.title('Temperature')
# Out:
# Text(0.5, 1.0, 'Temperature')

# %%
data3=np.loadtxt("pressure.xvg",skiprows=24)

# %%
plt.plot(data3[:,0],data3[:,1])
plt.xlabel('Time (ps)')
plt.ylabel('Pressure (bar)')
plt.title('Pressure')
# Out:
# Text(0.5, 1.0, 'Pressure')

# %%
data4=np.loadtxt("density.xvg",skiprows=24)

# %%
plt.plot(data4[:,0],data4[:,1])
plt.xlabel('Time (ps)')
plt.ylabel('Density (kg/m^3)')
plt.title('Density')
# Out:
# Text(0.5, 1.0, 'Density')
