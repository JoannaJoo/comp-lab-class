# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md

# %%
data=np.loadtxt("Runs/Water/Inputs/water_aimd_1ns_every0.5fs-1.ener",skiprows=1)

# %%
plt.plot(data[:,1],data[:,5])
plt.xlabel('Time (fs)')
plt.ylabel('Energy (a.u)')
plt.title('Time vs. Energy_water')
# Out:
# Text(0.5, 1.0, 'Time vs. Energy_water')

# %%
data=np.loadtxt("Runs/Proton/protom_aimd_1ns_every0.5fs-1.ener",skiprows=1)

plt.plot(data[:,1],data[:,5])
plt.xlabel('Time (fs)')
plt.ylabel('Energy (a.u)')
plt.title('Time vs. Energy_proton')
# Out:
# Text(0.5, 1.0, 'Time vs. Energy_proton')

# %%
import pandas as pd
from MDAnalysis.analysis import rdf
import numpy as np
import MDAnalysis as mda
from MDAnalysis.transformations.boxdimensions import set_dimensions

# %%
from matplotlib import pyplot as plt

# %%
u = mda.Universe("Runs/Water/Inputs/water_aimd_1ns_every0.5fs-pos-1.xyz")

# %%
dim = [12.42, 12.42, 12.42, 90, 90, 90]
#transform = set_dimensions(dim)

#u.trajectory.add_transformations(transform)
O = u.select_atoms('name O')
type2 = u.select_atoms('type 2')


ss_rdf = rdf.InterRDF(O,O)
ss_rdf.run();

# %%
ss_rdf.bins
# Out:
# array([ 0.1,  0.3,  0.5,  0.7,  0.9,  1.1,  1.3,  1.5,  1.7,  1.9,  2.1,
#         2.3,  2.5,  2.7,  2.9,  3.1,  3.3,  3.5,  3.7,  3.9,  4.1,  4.3,
#         4.5,  4.7,  4.9,  5.1,  5.3,  5.5,  5.7,  5.9,  6.1,  6.3,  6.5,
#         6.7,  6.9,  7.1,  7.3,  7.5,  7.7,  7.9,  8.1,  8.3,  8.5,  8.7,
#         8.9,  9.1,  9.3,  9.5,  9.7,  9.9, 10.1, 10.3, 10.5, 10.7, 10.9,
#        11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3, 12.5, 12.7, 12.9, 13.1,
#        13.3, 13.5, 13.7, 13.9, 14.1, 14.3, 14.5, 14.7, 14.9])

# %%
plt.plot(ss_rdf.bins, ss_rdf.rdf)
plt.xlabel('Radius (angstrom)')
plt.ylabel('Radial distribution')
plt.title('g (r)')
plt.ylim(0,4)
plt.show()
