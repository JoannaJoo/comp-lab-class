# %%
import mdtraj as md 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data=np.loadtxt("../Outputs/monitor/MONITOR-1.ener",skiprows=1)

# %%
plt.plot(data[:,1],data[:,4])
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (a.u.)')
plt.title('Time vs. Potential energy')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data2=np.loadtxt("../Outputs/monitor/MONITOR-COLVAR.metadynLog")
data3=np.loadtxt("../Outputs/metad1_initmonitor/METADYN-COLVAR.metadynLog")
data4=np.loadtxt("../Outputs/metad1_initmonitor_freqhills/METADYN-COLVAR.metadynLog")

# %%
plt.plot(data2[:,0],data2[:,1])
plt.xlabel('Time (fs)')
plt.ylabel('Reaction')
plt.title('Time vs. Reaction')
ax2 = ax1.twiny()

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.plot(data2[:,0],data2[:,1], color='red',label="MONITOR")

plt.plot(data3[:,0],data3[:,1], color='blue', label="metad1_initmonitor")
plt.plot(data4[:,0],data4[:,1], color='green', label= "metad1_initmonitor_freqhills")
plt.xlabel('Time (fs)')
plt.ylabel('Reaction')
plt.title('Time vs. Reaction')
plt.text(-500, -10.5, 'Hill frequency=100/Hill height=1.5/Hill width=0.5', fontsize=9)

fig.tight_layout()
plt.legend()
