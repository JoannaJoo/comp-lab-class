# %%
import mdtraj as md 
import numpy as np

# %%
data=np.loadtxt("../Outputs/NPT-1.ener",skiprows=1)

# %%
# !pwd
# Out:
# /home/jj3541/comp-lab-class/Week13/Analysis

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data[:,1],data[:,4])
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (a.u.)')
plt.title('Time vs. Potential energy_NPT-1')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data2=np.loadtxt("../Outputs/NVT-1.ener",skiprows=1)

# %%
plt.plot(data2[:,1],data2[:,4])
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (a.u.)')
plt.title('Time vs. Potential energy_NVT-1')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
